# %%
import json
from pathlib import Path
from collections import Counter
import pandas as pd
import sys

# Add project root to python path
# This handles both scripts (__file__) and notebooks (cwd)
try:
    project_root = Path(__file__).resolve().parent.parent
except NameError:
    # In Jupyter, use the current working directory's parent
    project_root = Path.cwd().parent

if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

from src.core.config import settings
from src.ingestion.loader import DataLoader

def profile_raw_data():
    print(f"Scanning data in: {settings.RAW_DATA_DIR}")
    
    # We'll use your existing loader to ensure we're reading the same way the app does
    loader = DataLoader(settings.RAW_DATA_DIR)
    
    sources_per_politician = {}
    unique_politician_names = Counter()
    total_articles = 0
    
    # We walk the directory to get article-level info directly
    json_files = list(settings.RAW_DATA_DIR.rglob("*.json"))
    
    for file_path in json_files:
        try:
            with open(file_path, "r", encoding="utf-8") as f:
                data = json.load(f)
            
            # Extract basic article metadata
            pol = data.get("politician", "Unknown")
            src = data.get("source", "Unknown")
            
            unique_politician_names[pol] += 1
            
            if pol not in sources_per_politician:
                sources_per_politician[pol] = Counter()
            
            sources_per_politician[pol][src] += 1
            total_articles += 1
            
        except Exception as e:
            print(f"Error reading {file_path.name}: {e}")

    # --- Print Results ---
    print("\n" + "="*50)
    print("RAJNEETI DATA PROFILE")
    print("="*50)
    print(f"Total JSON Articles Found: {total_articles}")
    
    print("\n1. Detected Politician Names (in JSON 'politician' field):")
    for name, count in unique_politician_names.items():
        print(f"   - {name}: {count} articles")

    print("\n2. Media Sources per Politician:")
    for pol, sources in sources_per_politician.items():
        print(f"\n--- {pol} ---")
        for src, count in sources.most_common():
            print(f"   - {src}: {count}")

    print("\n3. Overall Unique Sources Found:")
    all_sources = set()
    for sources in sources_per_politician.values():
        all_sources.update(sources.keys())
    for s in sorted(all_sources):
        print(f"   - {s}")
    print("="*50)

if __name__ == "__main__":
    profile_raw_data()
# Out:
# Scanning data in: E:\4thYear\Rajneeti\RAG_v3\raw_data
#
# ==================================================
# RAJNEETI DATA PROFILE
# ==================================================
# Total JSON Articles Found: 3043
#
# 1. Detected Politician Names (in JSON 'politician' field):
#    - Arvind Kejriwal: 128 articles
#    - N/A: 993 articles
#    - Sheila Dikshit: 14 articles
#    - Priyanka Gandhi Vadra: 4 articles
#    - Manish Sisodia: 6 articles
#    - Aam Aadmi Party (AAP): 1 articles
#    - Chandrababu Naidu: 4 articles
#    - Mamata Banerjee: 383 articles
#    - Narendra Modi: 89 articles
#    - Nitin Gadkari: 2 articles
#    - Gautam Gambhir: 8 articles
#    - Kanchan Chaudhary Bhattacharya: 1 articles
#    - Sukhpal Singh Khaira: 1 articles
#    - Meera Sanyal: 1 articles
#    - Alka Lamba: 4 articles
#    - Manmohan Singh: 3 articles
#    - Robert Vadra: 1 articles
#    - Rahul Gandhi: 17 articles
#    - Hardeep Singh Puri: 1 articles
#    - Navjot Singh Sidhu: 2 articles
#    - Amrinder Singh Raja Warring: 1 articles
#    - Hans Raj Hans: 1 articles
#    - Rajnath Singh: 2 articles
#    - Irom Sharmila: 1 articles
#    - N Chandrababu Naidu: 1 articles
#    - Bhagwant Mann: 1 articles
#    - Vijay Goel: 2 articles
#    - Sonia Gandhi: 1 articles
#    - Savukku Shankar: 1 articles
#    - Edapaddi K Palaniswami: 1 articles
#    - Senthil Balaji: 1 articles
#    - Kasthuri Shankar: 1 articles
#    - M. Karunanidhi: 1 articles
#    - Thulam Saravanan: 1 articles
#    - M. Sivasankar: 1 articles
#    - Arif Mohammad Khan: 4 articles
#    - P. V. Anvar: 1 articles
#    - Kerala Government: 1 articles
#    - Arif Mohammed Khan: 12 articles
#    - K N Balagopal: 2 articles
#    - Kerala Governor Rajendra Arlekar: 1 articles
#    - Saji Cheriyan: 1 articles
#    - Mallu Bhatti Vikramarka: 1 articles
#    - Prakash Javdekar: 1 articles
#    - K.K. Shailaja: 1 articles
#    - P. A. Mohamed Riyas: 1 articles
#    - Thomas Issac: 1 articles
#    - CM Pinarayi Vijayan: 2 articles
#    - V D Satheesan: 2 articles
#    - Adityanath: 25 articles
#    - Kerala FM Issac: 1 articles
#    - Rajendra Arlekar: 1 articles
#    - V. S. Achuthanandan: 1 articles
#    - K.N. Balagopal: 1 articles
#    - CM Pinarayi: 1 articles
#    - KT Jaleel: 1 articles
#    - Pinrayi Vijayan: 2 articles
#    - Kodiyeri Balakrishnan: 1 articles
#    - Shri Pinarayi Vijayan: 1 articles
#    - V. D. Satheesan: 1 articles
#    - Kerala CM: 1 articles
#    - KN Balagopal: 1 articles
#    - Pinarayi: 2 articles
#    - Arif Mohammad Khan, Pinarayi Vijayan: 1 articles
#    - CM Yogi: 2 articles
#    - Nand Kishor Gurjar: 1 articles
#    - Akhilesh Yadav: 2 articles
#    - Nitin Agrawal: 1 articles
#    - Sandeep Dayma: 1 articles
#    - CM Adityanath: 2 articles
#    - Shivraj Singh Chouhan: 1 articles
#    - Suresh Kumar Khanna: 1 articles
#    - Narendra Modi, Yogi Adityanath: 1 articles
#
# 2. Media Sources per Politician:
#
# --- Arvind Kejriwal ---
#    - ndtv: 105
#    - theprint.in: 20
#    - rediff: 2
#    - scroll.in: 1
#
# --- N/A ---
#    - Unknown: 529
#    - theprint.in: 155
#    - ndtv: 78
#    - scroll.in: 68
#    - rediff: 56
#    - thewire.in: 49
#    - thequint: 28
#    - indianexpress: 12
#    - thehindu: 9
#    - timesofindia.indiatimes: 7
#    - deccanherald: 2
#
# --- Sheila Dikshit ---
#    - ndtv: 8
#    - theprint.in: 6
#
# --- Priyanka Gandhi Vadra ---
#    - ndtv: 2
#    - scroll.in: 1
#    - thewire.in: 1
#
# --- Manish Sisodia ---
#    - ndtv: 4
#    - theprint.in: 2
#
# --- Aam Aadmi Party (AAP) ---
#    - theprint.in: 1
#
# --- Chandrababu Naidu ---
#    - theprint.in: 2
#    - ndtv: 1
#    - rediff: 1
#
# --- Mamata Banerjee ---
#    - rediff: 106
#    - theprint.in: 62
#    - thequint: 60
#    - thewire.in: 45
#    - scroll.in: 35
#    - indianexpress: 29
#    - timesofindia.indiatimes: 24
#    - thehindu: 14
#    - ndtv: 8
#
# --- Narendra Modi ---
#    - theprint.in: 37
#    - ndtv: 19
#    - scroll.in: 11
#    - thewire.in: 9
#    - rediff: 6
#    - thequint: 4
#    - timesofindia.indiatimes: 3
#
# --- Nitin Gadkari ---
#    - ndtv: 1
#    - theprint.in: 1
#
# --- Gautam Gambhir ---
#    - ndtv: 6
#    - theprint.in: 2
#
# --- Kanchan Chaudhary Bhattacharya ---
#    - theprint.in: 1
#
# --- Sukhpal Singh Khaira ---
#    - ndtv: 1
#
# --- Meera Sanyal ---
#    - ndtv: 1
#
# --- Alka Lamba ---
#    - ndtv: 4
#
# --- Manmohan Singh ---
#    - theprint.in: 1
#    - rediff: 1
#    - scroll.in: 1
#
# --- Robert Vadra ---
#    - ndtv: 1
#
# --- Rahul Gandhi ---
#    - theprint.in: 6
#    - ndtv: 5
#    - rediff: 2
#    - thequint: 2
#    - scroll.in: 2
#
# --- Hardeep Singh Puri ---
#    - ndtv: 1
#
# --- Navjot Singh Sidhu ---
#    - ndtv: 2
#
# --- Amrinder Singh Raja Warring ---
#    - ndtv: 1
#
# --- Hans Raj Hans ---
#    - ndtv: 1
#
# --- Rajnath Singh ---
#    - ndtv: 1
#    - theprint.in: 1
#
# --- Irom Sharmila ---
#    - ndtv: 1
#
# --- N Chandrababu Naidu ---
#    - ndtv: 1
#
# --- Bhagwant Mann ---
#    - ndtv: 1
#
# --- Vijay Goel ---
#    - ndtv: 2
#
# --- Prakash Javadekar ---
#    - ndtv: 2
#    - timesofindia.indiatimes: 1
#
# --- Raj Thackeray ---
#    - ndtv: 1
#    - theprint.in: 1
#    - rediff: 1
#
# --- Nitish Kumar ---
#    - theprint.in: 3
#    - scroll.in: 2
#    - thewire.in: 1
#    - thequint: 1
#
# --- Uddhav Thackeray ---
#    - ndtv: 2
#    - scroll.in: 1
#
# --- Udit Raj ---
#    - theprint.in: 1
#
# --- Harsh Vardhan ---
#    - ndtv: 1
#
# --- Kapil Mishra ---
#    - ndtv: 2
#    - theprint.in: 2
#
# --- Manohar Lal Khattar ---
#    - theprint.in: 1
#
# --- Sandeep Kumar ---
#    - theprint.in: 1
#
# --- Babul Supriyo ---
#    - theprint.in: 1
#    - scroll.in: 1
#
# --- Anna Hazare ---
#    - ndtv: 1
#
# --- Rajinikanth ---
#    - ndtv: 2
#
# --- Aam Aadmi Party ---
#    - ndtv: 1
#
# --- Arun Jaitley ---
#    - ndtv: 1
#
# --- Alok Verma ---
#    - ndtv: 1
#
# --- Smriti Irani ---
#    - ndtv: 1
#    - theprint.in: 1
#
# --- V.K. Singh ---
#    - theprint.in: 1
#
# --- CR Patil ---
#    - ndtv: 1
#
# --- Shashi Tharoor ---
#    - ndtv: 2
#    - theprint.in: 1
#    - indianexpress: 1
#
# --- HS Phoolka ---
#    - ndtv: 1
#
# --- Manoj Tiwari ---
#    - ndtv: 1
#
# --- Prakash Raj ---
#    - theprint.in: 1
#
# --- N. Chandrababu Naidu ---
#    - theprint.in: 1
#
# --- Raghav Chadha ---
#    - ndtv: 1
#
# --- Congress Party ---
#    - ndtv: 1
#
# --- Yogi Adityanath ---
#    - theprint.in: 122
#    - rediff: 79
#    - thequint: 50
#    - thewire.in: 33
#    - scroll.in: 15
#
# --- Amarinder Singh ---
#    - theprint.in: 1
#    - ndtv: 1
#
# --- Amit Mitra ---
#    - rediff: 1
#    - theprint.in: 1
#
# --- Abhishek Banerjee ---
#    - thewire.in: 2
#    - scroll.in: 2
#    - theprint.in: 2
#    - rediff: 1
#
# --- Amit Shah ---
#    - rediff: 4
#    - scroll.in: 4
#    - thequint: 2
#    - thewire.in: 1
#
# --- JP Nadda ---
#    - rediff: 1
#
# --- Ashis Das ---
#    - scroll.in: 1
#
# --- Narendra Modi, Mamata Banerjee ---
#    - thequint: 1
#
# --- J.P. Nadda ---
#    - indianexpress: 1
#
# --- Gajendra Singh Shekhawat ---
#    - theprint.in: 1
#
# --- Aaditya Thackeray ---
#    - theprint.in: 1
#
# --- Mahua Moitra ---
#    - theprint.in: 4
#    - thequint: 2
#    - scroll.in: 1
#
# --- Dinesh Trivedi ---
#    - theprint.in: 1
#
# --- Sukanta Majumdar ---
#    - scroll.in: 1
#
# --- Congress ---
#    - theprint.in: 1
#
# --- Arun Govil ---
#    - theprint.in: 1
#
# --- Suvendu Adhikari ---
#    - theprint.in: 3
#    - scroll.in: 2
#    - thequint: 1
#
# --- Sushilkumar Shinde ---
#    - rediff: 1
#
# --- Alapan Bandyopadhyay ---
#    - rediff: 1
#
# --- Locket Chatterjee ---
#    - theprint.in: 1
#
# --- Sanjay Raut ---
#    - scroll.in: 1
#
# --- Hiran Chatterjee ---
#    - theprint.in: 1
#
# --- Asaduddin Owaisi ---
#    - theprint.in: 2
#
# --- Sharad Pawar ---
#    - scroll.in: 1
#
# --- Siddaramaiah ---
#    - theprint.in: 2
#
# --- M.K. Stalin ---
#    - theprint.in: 8
#    - ndtv: 3
#    - rediff: 1
#    - thewire.in: 1
#    - scroll.in: 1
#
# --- Satabdi Roy ---
#    - scroll.in: 2
#
# --- Mayawati ---
#    - theprint.in: 2
#
# --- Modi ---
#    - rediff: 1
#
# --- K. Chandrashekar Rao ---
#    - rediff: 1
#    - theprint.in: 1
#
# --- Mithun Chakraborty ---
#    - scroll.in: 2
#    - theprint.in: 1
#
# --- Multiple Politicians (West Bengal) ---
#    - thewire.in: 1
#
# --- Pinarayi Vijayan ---
#    - timesofindia.indiatimes: 141
#    - theprint.in: 106
#    - indianexpress: 80
#    - rediff: 60
#    - scroll.in: 51
#    - thequint: 40
#    - thehindu: 38
#    - thewire.in: 19
#    - deccanherald: 6
#    - ndtv: 1
#
# --- Firhad Hakim ---
#    - indianexpress: 1
#
# --- KCR ---
#    - rediff: 1
#
# --- Kamal Haasan ---
#    - ndtv: 5
#    - theprint.in: 2
#
# --- Yashwant Sinha ---
#    - scroll.in: 1
#
# --- Ashwani Vaishnaw ---
#    - theprint.in: 1
#
# --- Tejashwi Yadav ---
#    - theprint.in: 1
#
# --- Churchill Alemao ---
#    - theprint.in: 1
#
# --- MK Stalin ---
#    - ndtv: 67
#    - theprint.in: 25
#    - scroll.in: 13
#
# --- Bimal Gurung ---
#    - theprint.in: 1
#
# --- Oommen Chandy ---
#    - thehindu: 2
#    - scroll.in: 1
#
# --- Prashant Kishor ---
#    - ndtv: 3
#    - scroll.in: 1
#    - theprint.in: 1
#
# --- Ashwini Vaishnaw ---
#    - scroll.in: 1
#
# --- CV Ananda Bose ---
#    - scroll.in: 1
#
# --- Chandan Mitra ---
#    - scroll.in: 1
#
# --- Rajib Banerjee ---
#    - scroll.in: 1
#
# --- Conrad K. Sangma ---
#    - theprint.in: 1
#
# --- M. K. Stalin ---
#    - theprint.in: 29
#    - thewire.in: 1
#    - ndtv: 1
#
# --- Bharati Ghosh ---
#    - theprint.in: 1
#
# --- Kailash Vijayvargiya ---
#    - scroll.in: 1
#
# --- Mukul Roy ---
#    - theprint.in: 1
#
# --- Jawhar Sircar ---
#    - thequint: 1
#
# --- Chandra Kumar Bose ---
#    - theprint.in: 1
#
# --- Prithviraj Chavan ---
#    - thequint: 1
#
# --- Dola Sen ---
#    - theprint.in: 1
#
# --- Bharatiya Janata Party (BJP) ---
#    - thequint: 1
#    - scroll.in: 1
#
# --- B. S. Yediyurappa ---
#    - theprint.in: 1
#
# --- CM Ibrahim ---
#    - theprint.in: 1
#
# --- Bidyut Chakrabarty ---
#    - thewire.in: 1
#
# --- Eknath Shinde ---
#    - rediff: 1
#
# --- BJP ---
#    - thewire.in: 1
#
# --- Mamata ---
#    - rediff: 1
#
# --- Kalyan Banerjee ---
#    - indianexpress: 1
#
# --- Om Prakash Rajbhar ---
#    - rediff: 1
#
# --- Srabanti Chatterjee ---
#    - scroll.in: 1
#
# --- Shahjahan Sheikh ---
#    - timesofindia.indiatimes: 1
#
# --- Tejasvi Surya ---
#    - theprint.in: 1
#
# --- Rajendra Rathore ---
#    - theprint.in: 1
#
# --- V.D. Satheesan ---
#    - theprint.in: 1
#
# --- Adhir Ranjan Chowdhury ---
#    - theprint.in: 1
#
# --- Pranab Mukherjee ---
#    - theprint.in: 1
#
# --- Udhayanidhi Stalin ---
#    - theprint.in: 14
#    - scroll.in: 9
#    - ndtv: 6
#    - thewire.in: 1
#
# --- Jyoti Priya Mallick ---
#    - scroll.in: 1
#
# --- Kristalina Georgieva ---
#    - ndtv: 1
#
# --- Dr. P. Thiaga Rajan (PTR) ---
#    - theprint.in: 1
#
# --- J. Jayalalithaa ---
#    - theprint.in: 1
#    - ndtv: 1
#
# --- Bhumana Karunakar Reddy ---
#    - theprint.in: 1
#
# --- Edapaddi Palaniswami ---
#    - ndtv: 1
#
# --- A. Raja ---
#    - theprint.in: 1
#
# --- Thol. Thirumavalavan ---
#    - theprint.in: 1
#
# --- M K Stalin ---
#    - ndtv: 8
#    - theprint.in: 6
#
# --- Udhayanidhi ---
#    - theprint.in: 1
#
# --- Edappadi K Palaniswami ---
#    - ndtv: 2
#    - scroll.in: 1
#
# --- K Annamalai ---
#    - scroll.in: 1
#    - theprint.in: 1
#
# --- Palanivel Thiaga Rajan ---
#    - theprint.in: 3
#    - scroll.in: 1
#
# --- Khushbu Sundar ---
#    - ndtv: 1
#
# --- O Panneerselvam ---
#    - ndtv: 2
#
# --- Edappadi K. Palaniswami (EPS) ---
#    - theprint.in: 1
#
# --- Nirmala Sitharaman ---
#    - theprint.in: 1
#
# --- V Narayanasamy ---
#    - ndtv: 1
#
# --- Y. S. Jaganmohan Reddy ---
#    - thewire.in: 1
#
# --- Vijayakanth ---
#    - theprint.in: 1
#
# --- DMK ---
#    - theprint.in: 1
#
# --- Edappadi Palaniswami ---
#    - ndtv: 2
#
# --- KC Veeramani ---
#    - ndtv: 1
#
# --- PM Modi ---
#    - ndtv: 1
#
# --- Bernie Sanders ---
#    - ndtv: 1
#
# --- Vijay ---
#    - theprint.in: 2
#    - thewire.in: 1
#
# --- VK Sasikala ---
#    - ndtv: 1
#
# --- Annamalai ---
#    - theprint.in: 1
#
# --- Shobha Karandlaje ---
#    - theprint.in: 1
#
# --- Thanga Kathiravan ---
#    - ndtv: 1
#
# --- K. Chandrasekhar Rao ---
#    - ndtv: 1
#
# --- Basavaraj Bommai ---
#    - theprint.in: 1
#    - rediff: 1
#
# --- K Ponmudy ---
#    - scroll.in: 2
#
# --- Tamilisai Soundararajan ---
#    - theprint.in: 1
#
# --- O. Panneerselvam, T. T. V. Dhinakaran ---
#    - theprint.in: 1
#
# --- K Armstrong ---
#    - scroll.in: 1
#
# --- R. N. Ravi ---
#    - theprint.in: 4
#
# --- KS Alagiri ---
#    - ndtv: 1
#
# --- D. K. Shivakumar ---
#    - theprint.in: 1
#
# --- RN Ravi ---
#    - scroll.in: 3
#
# --- K. Ponmudy ---
#    - theprint.in: 1
#
# --- V Senthil Balaji ---
#    - scroll.in: 2
#
# --- M. K. Alagiri ---
#    - theprint.in: 1
#
# --- Mani Shankar Aiyar ---
#    - ndtv: 1
#
# --- K Palaniswami ---
#    - ndtv: 1
#
# --- P. Thiaga Rajan ---
#    - theprint.in: 1
#
# --- Mohandas Gandhi ---
#    - scroll.in: 1
#
# --- D. N. V. Senthil Kumar ---
#    - theprint.in: 1
#
# --- Edappadi Karuppa Palaniswami ---
#    - ndtv: 1
#
# --- A Raja ---
#    - ndtv: 1
#    - scroll.in: 1
#
# --- Dr C Vijaya Baskar ---
#    - ndtv: 1
#
# --- J Jayalalithaa ---
#    - ndtv: 1
#
# --- S Jagathrakshakan ---
#    - scroll.in: 1
#
# --- R.N. Ravi ---
#    - theprint.in: 1
#
# --- PK Sekar Babu ---
#    - ndtv: 1
#
# --- VK Pandian ---
#    - scroll.in: 1
#
# --- Ma Foi Pandiarajan ---
#    - ndtv: 1
#
# --- T Raja Singh ---
#    - theprint.in: 1
#
# --- Thalapathy Vijay ---
#    - theprint.in: 1
#
# --- Edappadi K. Palaniswami ---
#    - theprint.in: 1
#
# --- N Rangaswamy ---
#    - ndtv: 1
#
# --- Anbil Mahesh Poyyamozhi ---
#    - ndtv: 1
#
# --- Sonia Gandhi ---
#    - ndtv: 1
#
# --- Savukku Shankar ---
#    - theprint.in: 1
#
# --- Edapaddi K Palaniswami ---
#    - ndtv: 1
#
# --- Senthil Balaji ---
#    - theprint.in: 1
#
# --- Kasthuri Shankar ---
#    - theprint.in: 1
#
# --- M. Karunanidhi ---
#    - theprint.in: 1
#
# --- Thulam Saravanan ---
#    - ndtv: 1
#
# --- M. Sivasankar ---
#    - theprint.in: 1
#
# --- Arif Mohammad Khan ---
#    - scroll.in: 2
#    - rediff: 1
#    - thewire.in: 1
#
# --- P. V. Anvar ---
#    - theprint.in: 1
#
# --- Kerala Government ---
#    - scroll.in: 1
#
# --- Arif Mohammed Khan ---
#    - rediff: 4
#    - scroll.in: 2
#    - thequint: 2
#    - timesofindia.indiatimes: 1
#    - theprint.in: 1
#    - indianexpress: 1
#    - thewire.in: 1
#
# --- K N Balagopal ---
#    - timesofindia.indiatimes: 1
#    - theprint.in: 1
#
# --- Kerala Governor Rajendra Arlekar ---
#    - theprint.in: 1
#
# --- Saji Cheriyan ---
#    - rediff: 1
#
# --- Mallu Bhatti Vikramarka ---
#    - thewire.in: 1
#
# --- Prakash Javdekar ---
#    - theprint.in: 1
#
# --- K.K. Shailaja ---
#    - thewire.in: 1
#
# --- P. A. Mohamed Riyas ---
#    - theprint.in: 1
#
# --- Thomas Issac ---
#    - rediff: 1
#
# --- CM Pinarayi Vijayan ---
#    - deccanherald: 1
#    - timesofindia.indiatimes: 1
#
# --- V D Satheesan ---
#    - timesofindia.indiatimes: 2
#
# --- Adityanath ---
#    - scroll.in: 20
#    - thewire.in: 5
#
# --- Kerala FM Issac ---
#    - rediff: 1
#
# --- Rajendra Arlekar ---
#    - scroll.in: 1
#
# --- V. S. Achuthanandan ---
#    - thehindu: 1
#
# --- K.N. Balagopal ---
#    - timesofindia.indiatimes: 1
#
# --- CM Pinarayi ---
#    - thequint: 1
#
# --- KT Jaleel ---
#    - timesofindia.indiatimes: 1
#
# --- Pinrayi Vijayan ---
#    - timesofindia.indiatimes: 2
#
# --- Kodiyeri Balakrishnan ---
#    - timesofindia.indiatimes: 1
#
# --- Shri Pinarayi Vijayan ---
#    - thewire.in: 1
#
# --- V. D. Satheesan ---
#    - theprint.in: 1
#
# --- Kerala CM ---
#    - thequint: 1
#
# --- KN Balagopal ---
#    - scroll.in: 1
#
# --- Pinarayi ---
#    - indianexpress: 2
#
# --- Arif Mohammad Khan, Pinarayi Vijayan ---
#    - theprint.in: 1
#
# --- CM Yogi ---
#    - thequint: 1
#    - theprint.in: 1
#
# --- Nand Kishor Gurjar ---
#    - theprint.in: 1
#
# --- Akhilesh Yadav ---
#    - rediff: 1
#    - theprint.in: 1
#
# --- Nitin Agrawal ---
#    - theprint.in: 1
#
# --- Sandeep Dayma ---
#    - thequint: 1
#
# --- CM Adityanath ---
#    - scroll.in: 1
#    - thequint: 1
#
# --- Shivraj Singh Chouhan ---
#    - theprint.in: 1
#
# --- Suresh Kumar Khanna ---
#    - rediff: 1
#
# --- Narendra Modi, Yogi Adityanath ---
#    - thequint: 1
#
# 3. Overall Unique Sources Found:
#    - Unknown
#    - deccanherald
#    - indianexpress
#    - ndtv
#    - rediff
#    - scroll.in
#    - thehindu
#    - theprint.in
#    - thequint
#    - thewire.in
#    - timesofindia.indiatimes
# ==================================================
